# %%
import os
from conllu import parse

def load_conllu_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = f.read()
    return parse(data)

def basic_stats(conllu_data):
    num_sentences = len(conllu_data)
    sentence_lengths = [int(sentence.metadata['sent_len']) for sentence in conllu_data]
    avg_length = sum(sentence_lengths) / num_sentences
    sorted_lengths = sorted(sentence_lengths)
    median_length = sorted_lengths[num_sentences // 2]
    min_length = min(sentence_lengths)
    max_length = max(sentence_lengths)
    return {
        'Nombre de phrases': num_sentences,
        'Taille moyenne de phrase': avg_length,
        'Taille médiane de phrase': median_length,
        'Taille de la plus petite phrase': min_length,
        'Taille de la plus grande phrase': max_length
    }

def process_folder(folder_path):
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".conllu"):
                file_path = os.path.join(root, file)
                print(f"Traitement de {file_path}")
                conllu_data = load_conllu_file(file_path)
                stats = basic_stats(conllu_data)

                for stat, value in stats.items():
                    print(f"{stat}: {value}")
                print("\n")

if __name__ == "__main__":
    conllu_folder_path = "/home/ziane212/Téléchargements/1665_abrege"  # Remplacez avec le chemin de votre dossier contenant les fichiers CoNLL-U
    process_folder(conllu_folder_path)
# Out:
# Traitement de /home/ziane212/Téléchargements/1665_abrege/1665_Abrege_reorder_gr9.conllu
# Nombre de phrases: 2
# Taille moyenne de phrase: 106.5
# Taille médiane de phrase: 108
# Taille de la plus petite phrase: 105
# Taille de la plus grande phrase: 108
#
#
# Traitement de /home/ziane212/Téléchargements/1665_abrege/1665_Abrege_reorder_gr8.conllu
# Nombre de phrases: 1
# Taille moyenne de phrase: 91.0
# Taille médiane de phrase: 91
# Taille de la plus petite phrase: 91
# Taille de la plus grande phrase: 91
#
#
# Traitement de /home/ziane212/Téléchargements/1665_abrege/1665_Abrege_reorder_gr7.conllu
# Nombre de phrases: 3
# Taille moyenne de phrase: 83.33333333333333
# Taille médiane de phrase: 82
# Taille de la plus petite phrase: 82
# Taille de la plus grande phrase: 86
#
#
# Traitement de /home/ziane212/Téléchargements/1665_abrege/1665_Abrege_reorder_gr6.conllu
# Nombre de phrases: 19
# Taille moyenne de phrase: 74.26315789473684
# Taille médiane de phrase: 74
# Taille de la plus petite phrase: 71
# Taille de la plus grande phrase: 79
#
#
# Traitement de /home/ziane212/Téléchargements/1665_abrege/1665_Abrege_reorder_gr5.conllu
# Nombre de phrases: 40
# Taille moyenne de phrase: 65.3
# Taille médiane de phrase: 66
# Taille de la plus petite phrase: 61
# Taille de la plus grande phrase: 69
#
#
# Traitement de /home/ziane212/Téléchargements/1665_abrege/1665_Abrege_reorder_gr4.conllu
# Nombre de phrases: 88
# Taille moyenne de phrase: 54.13636363636363
# Taille médiane de phrase: 54
# Taille de la plus petite phrase: 51
# Taille de la plus grande phrase: 59
#
#
# Traitement de /home/ziane212/Téléchargements/1665_abrege/1665_Abrege_reorder_gr3.conllu
# Nombre de phrases: 163
# Taille moyenne de phrase: 45.01840490797546
# Taille médiane de phrase: 45
# Taille de la plus petite phrase: 41
# Taille de la plus grande phrase: 49
#
#
# Traitement de /home/ziane212/Téléchargements/1665_abrege/1665_Abrege_reorder_gr2.conllu
# Nombre de phrases: 310
# Taille moyenne de phrase: 34.57419354838709
# Taille médiane de phrase: 34
# Taille de la plus petite phrase: 31
# Taille de la plus grande phrase: 39
#
#
# Traitement de /home/ziane212/Téléchargements/1665_abrege/1665_Abrege_reorder_gr1.conllu
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/conllu/parser.py:131, in parse_line(line, fields, field_parsers)
#     130 try:
# --> 131     value = field_parsers[field](line_split, i)
#     132 except ParseException as e:
#
# File ~/anaconda3/lib/python3.10/site-packages/conllu/parser.py:16, in <lambda>(line, i)
#      11 DEFAULT_FIELDS = ('id', 'form', 'lemma', 'upos', 'xpos', 'feats', 'head', 'deprel', 'deps', 'misc')
#      12 DEFAULT_FIELD_PARSERS: T.Dict[str, _FieldParserType] = {
#      13     "id": lambda line, i: parse_id_value(line[i]),
#      14     "xpos": lambda line, i: parse_nullable_value(line[i]),
#      15     "feats": lambda line, i: parse_dict_value(line[i]),
# ---> 16     "head": lambda line, i: parse_int_value(line[i]),
#      17     "deps": lambda line, i: parse_paired_list_value(line[i]),
#      18     "misc": lambda line, i: parse_dict_value(line[i]),
#      19 }
#      20 DEFAULT_METADATA_PARSERS: T.Dict[str, _MetadataParserType] = {
#      21     "newpar": lambda key, value: (key, value),
#      22     "newdoc": lambda key, value: (key, value),
#      23 }
#
# File ~/anaconda3/lib/python3.10/site-packages/conllu/parser.py:195, in parse_int_value(value)
#     194 else:
# --> 195     raise ParseException("'{}' is not a valid value for parse_int_value.".format(value))
#
# ParseException: 'NPRS' is not a valid value for parse_int_value.
#
# During handling of the above exception, another exception occurred:
#
# ParseException                            Traceback (most recent call last)
# Cell In[5], line 40
#      38 if __name__ == "__main__":
#      39     conllu_folder_path = "/home/ziane212/Téléchargements/1665_abrege"  # Remplacez avec le chemin de votre dossier contenant les fichiers CoNLL-U
# ---> 40     process_folder(conllu_folder_path)
#
# Cell In[5], line 31, in process_folder(folder_path)
#      29 file_path = os.path.join(root, file)
#      30 print(f"Traitement de {file_path}")
# ---> 31 conllu_data = load_conllu_file(file_path)
#      32 stats = basic_stats(conllu_data)
#      34 for stat, value in stats.items():
#
# Cell In[5], line 7, in load_conllu_file(file_path)
#       5 with open(file_path, 'r', encoding='utf-8') as f:
#       6     data = f.read()
# ----> 7 return parse(data)
#
# File ~/anaconda3/lib/python3.10/site-packages/conllu/__init__.py:19, in parse(data, fields, field_parsers, metadata_parsers)
#      15 def parse(data: str, fields: T.Optional[T.Sequence[str]] = None,
#      16           field_parsers: T.Optional[T.Dict[str, _FieldParserType]] = None,
#      17           metadata_parsers: T.Optional[T.Dict[str, _MetadataParserType]] = None
#      18           ) -> SentenceList:
# ---> 19     return SentenceList(parse_incr(
#      20         StringIO(data),
#      21         fields=fields,
#      22         field_parsers=field_parsers,
#      23         metadata_parsers=metadata_parsers
#      24     ))
#
# File ~/anaconda3/lib/python3.10/site-packages/conllu/models.py:303, in SentenceList.__init__(self, sentences, metadata)
#     300 sentences = sentences or []
#     302 if hasattr(sentences, "__next__"):
# --> 303     sentences = list(sentences)
#     305 if not isinstance(sentences, list):
#     306     raise ParseException("Can't create SentenceList, sentences is not a list.")
#
# File ~/anaconda3/lib/python3.10/site-packages/conllu/__init__.py:39, in parse_incr.<locals>.generator()
#      37 def generator():
#      38     for sentence in parse_sentences(in_file):
# ---> 39         yield parse_token_and_metadata(
#      40             sentence,
#      41             fields=fields,
#      42             field_parsers=field_parsers,
#      43             metadata_parsers=metadata_parsers
#      44         )
#
# File ~/anaconda3/lib/python3.10/site-packages/conllu/parser.py:96, in parse_token_and_metadata(data, fields, field_parsers, metadata_parsers)
#      94             metadata[key] = value
#      95     else:
# ---> 96         tokens.append(parse_line(line, fields, field_parsers))
#      98 return TokenList(tokens, metadata, default_fields=fields)
#
# File ~/anaconda3/lib/python3.10/site-packages/conllu/parser.py:133, in parse_line(line, fields, field_parsers)
#     131         value = field_parsers[field](line_split, i)
#     132     except ParseException as e:
# --> 133         raise ParseException("Failed parsing field '{}': ".format(field) + str(e))
#     135 else:
#     136     value = line_split[i]
#
# ParseException: Failed parsing field 'head': 'NPRS' is not a valid value for parse_int_value.
