# %%
from lxml import etree

# %%
path_in = r"C:\Users\yagam\Downloads\1665_Abrege_Final_tagconv_test.xml"                  

path_out = r"C:\Users\yagam\Downloads\1665_Abrege_Final_tagconv_test1.xml"

# %%
tree = etree.parse(open(path_in, encoding='utf-8'))
root = tree.getroot()

test_ = []
l_numSG = ['un']

for id_, s in enumerate(root.findall('.//s')):
    
    for id_w, w in enumerate(s.findall('.//w')):
        l_function_noConv = ['root', 'acl:relcl', 'advcl', 'acl']
        if w.get('uppos') ==  '_' and w.get('prpos') ==  '_' and w.get('function') in l_function_noConv and w.get('udpos')=='VERB':
            id_parent = w.get('n')
            print(w.text)
            
            for w2 in root.findall('.//s')[id_]:

                var = False
                if w2.get('head') == id_parent and w2.get('udpos') == 'AUX':
                            
                    var = True
                
            if var == False:
                w.set('uppos', 'VJ')
                w.set('prpos', 'Vvc')
            
            elif var == True:
                w.set('uppos', 'VPP')
                w.set('prpos', 'Ge')
                
            w.set('convNoMatching', 'Yes')
        '''    
        if w.get('uppos') ==  'NCS' or w.get('uppos') ==  'NPRS':
            id_gov = w.get('n')
            
            for w2 in root.findall('.//s')[id_]:
                
                id_dep = w2.get('n')
                
                if w2.get('head') == id_gov and w2.get('function') == 'nummod' and id_gov > id_dep:
                    
                    if w.get('lemma') in l_numSG:
                        pass
                    else:
                        if w.get('uppos') ==  'NCS':
                            w.set('uppos', 'NCPL')
                            w.set('annot_PL', "nummod")
                        if w.get('uppos') ==  'NPRS':
                            w.set('uppos', 'NPRPL')
                            w.set('annot_PL', "nummod")                            
                
                if w2.get('head') == id_gov and w2.get('udpos')=='DET' and (w2.text.endswith('s') or w2.text.endswith('z') or w2.text.endswith('x')):                                                              
                    if w.get('uppos') ==  'NCS':
                        w.set('uppos', 'NCPL')
                        w.set('annot_PL', "nummod")
                    if w.get('uppos') ==  'NPRS':
                        w.set('uppos', 'NPRPL')
                        w.set('annot_PL', "nummod")

                if w2.get('head') == id_gov and (w2.attrib('lemma')=='à+le' or w2.attrib('lemma')=='de+le'):                                                              
                    if w.get('uppos') ==  'NCS':
                        w.set('uppos', 'NCPL')
                        w.set('annot_PL', "nummod")
                    if w.get('uppos') ==  'NPRS':
                        w.set('uppos', 'NPRPL')
                        w.set('annot_PL', "nummod")
        '''
# Out:
# escriuoit
# enuoyoie[n]t
# trauersée
# soûleuerent
# assommirent
# trouuerent
# arriuerent
# reserua
# acheua
# trouuasmes
# aduisa
# trauaillées
# conseruerent
# acheua
# trouuerent
# suiuoient
# sauua
# conuia
# vsurperent
# effectiue
# leua
# conuainc
# suruesquit
# reuindrent
# trauersé
# aduoüé
# iniuriez
# reietta
# renuoya
# deuenoit
# trouuerent
# leua
# reuenoit
# éuenté
# viuroient
# trouuerent
# saoula
# sauua
# acheuée
# iustifia
# acheuée
# acheua
# reseruoit
# seruoit
# conuenu
# trauaillerent
# acheua
# fauorisoient
# seruirent
# sauuerent
# deliura
# conseruerent
# preuint
# conuierent
# aduiserent
# acheuoit
# auerti
# reietta
# sauua
# fauorisoit
# contreuint
# adiourné
# coniurer
# suruenuë
# reiointe
# mocqua-t'
# rauoir
# releua
#
#
# sçauoient
# preuenus
# sauua
# rauagé
# acheua
# redeuint
# sauuerent
# preuaut
# ioüerent
# suiuoient
# appauury
# suruenuë
#
#
# trauailla
# releua
# enuoyerent
# acheuast
# acheua
# iugerent
# renuoyée
# ietoit
# gouuernoient
# trouuerent
# renuoya
# sauua
# suruesquit
#
#
# suruenuë
# auança
# enleuerent
# reueu
# diuertissant
# suruenuë
# aioutast
# beuuoit
# acheua
# trauersé
# aduança
# arriuerent
# adiuster
# renuoyer
# seruoit-
# enuoyerent
# enuoye[n]s
# suruenuë
# iurerent
# suruequit
# seruirent
# conuoquoit
# reioigne
# trauersa
# sauua
# preuint
# reuenoient
# prouignée
# desaduoüa
#
#
# contreuinssent
# trouuerent
# suiuoient
# trauailla
# enuoyerent
# auança
# sauua
# releuerent
# auança
# auancerent
# leuerent
# sauua
# retapirent
# conseruerent
# suruinrent
# redeuinrent
# deuenoit
# proietté
# raieunir
# reuoqua
# preuenus
# auiser
# sauuerent
# sousleuée
# diuerir
# trauailloit
# inuestis
# reuenoit
# acheua
# reuinrent
# auança
# acheua
# acheua
# reuindrent
# acheuée

# %%
def indent(elem, level=0, more_sibs=False):
    i = "\n"
    if level:
        i += (level-1) * '\t'
    num_kids = len(elem)
    if num_kids:
        if not elem.text or not elem.text.strip():
            elem.text = i + "\t"
            if level:
                elem.text += '\t'
        count = 0
        for kid in elem:
            indent(kid, level+1, count < num_kids - 1)
            count += 1
        if not elem.tail or not elem.tail.strip():
            elem.tail = i
            if more_sibs:
                elem.tail += '\t'
    else:
        if level and (not elem.tail or not elem.tail.strip()):
            elem.tail = i
            if more_sibs:
                elem.tail += '\t'

# %%
indent(root)
#etree.dump(new_root)
etree.ElementTree(root).write(path_out, encoding='utf-8')
